# %%
import numpy as np
import cv2
import tensorflow as tf
import os

from matplotlib import pyplot as plt
from tensorflow.keras.models import load_model

# %%
model = load_model(os.path.join('models','pizza_quality_classifier.h5'))

# %%
img = cv2.imread('overtest1.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
np.expand_dims(resize, 0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))

# %%
yhat
# Out:
# array([[0.08988389]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Standard')
else:
    print(f'Predicted class is Not the Standard')
# Out:
# Predicted class is Not the Standard
